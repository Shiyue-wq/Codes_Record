# %%
import pandas as pd
stock_rerurn = "/Users/wwwzhang/Documents/FIN3210/Week3 Assignment/FIN3210 Week 3 Stock returns.xlsx"
df = pd.read_excel(stock_rerurn, sheet_name='data')

# %%
import matplotlib.pyplot as plt

# %%
df['month'] = pd.to_datetime(df['month'])
df['quarter'] = df['month'].dt.to_period('Q').dt.strftime('%YQ%q')
df.reset_index()
# Out:
#        index   stkcd stknme         conme      month    retrf   mktrf     smb  \
# 0          0       9   中国宝安  中国宝安集团股份有限公司 2013-07-01   9.0756  1.8833  5.1896
# 1          1       9   中国宝安  中国宝安集团股份有限公司 2013-08-01  -5.1363  4.5833  5.9407
# 2          2       9   中国宝安  中国宝安集团股份有限公司 2013-09-01   3.5840  3.3833  0.5848
# 3          3       9   中国宝安  中国宝安集团股份有限公司 2014-01-01  -1.0932 -3.6167  5.6921
# 4          4       9   中国宝安  中国宝安集团股份有限公司 2014-02-01  19.0704  0.9833  3.8899
# ...      ...     ...    ...           ...        ...      ...     ...     ...
# 87427  87427  900956   东贝B股  黄石东贝电器股份有限公司 2019-08-01  -5.3373 -1.6917 -0.6838
# 87428  87428  900956   东贝B股  黄石东贝电器股份有限公司 2019-09-01  11.0761  0.4083  0.4298
# 87429  87429  900956   东贝B股  黄石东贝电器股份有限公司 2019-10-01  12.3759  1.3083 -2.5189
# 87430  87430  900956   东贝B股  黄石东贝电器股份有限公司 2019-11-01   0.5954 -1.6917 -0.8970
# 87431  87431  900956   东贝B股  黄石东贝电器股份有限公司 2019-12-01   7.2701  6.2083  1.2581
#
#           hml     umd  ...        bm   return12       roa       lev       ppe  \
# 0     -0.1922  6.1829  ...  0.438860  13.374120  0.007949  0.430605  0.086185
# 1      0.0976 -5.5041  ...  0.438860  13.374120  0.007949  0.430605  0.086185
# 2      2.8554  8.8693  ...  0.438860  13.374120  0.007949  0.430605  0.086185
# 3      1.1126  8.9357  ...  0.394303  46.591590  0.025973  0.432246  0.098660
# 4      0.6902 -1.8764  ...  0.394303  46.591590  0.025973  0.432246  0.098660
# ...       ...     ...  ...       ...        ...       ...       ...       ...
# 87427 -5.0887  4.6431  ...  5.124264  -4.492293  0.005443  0.598459  0.267594
# 87428  0.8208 -1.3250  ...  5.124264  -4.492293  0.005443  0.598459  0.267594
# 87429 -0.0984  3.5783  ...  5.950344 -14.776860  0.010888  0.425125  0.269671
# 87430  0.1604 -0.1658  ...  5.950344 -14.776860  0.010888  0.425125  0.269671
# 87431 -0.9661  1.0033  ...  5.950344 -14.776860  0.010888  0.425125  0.269671
#
#          intang  numanalyst  instown           mv  quarter
# 0      0.031575           0   6.4646  11874173952   2013Q3
# 1      0.031575           0   6.4646  11874173952   2013Q3
# 2      0.031575           0   6.4646  11874173952   2013Q3
# 3      0.029798           0   5.6741  11731143680   2014Q1
# 4      0.029798           0   5.6741  11731143680   2014Q1
# ...         ...         ...      ...          ...      ...
# 87427  0.025879           0   0.0000    131675000   2019Q3
# 87428  0.025879           0   0.0000    131675000   2019Q3
# 87429  0.025286           0   0.0000    127880000   2019Q4
# 87430  0.025286           0   0.0000    127880000   2019Q4
# 87431  0.025286           0   0.0000    127880000   2019Q4
#
# [87432 rows x 21 columns]

# %%
def assign_quintile(df,stand):
    df_p = df.copy()
    df_p['label'] = df_p.groupby('quarter')[stand].transform(
        lambda x: pd.qcut(x, 5, labels=False, duplicates='drop') + 1
    )
    return df_p

# %%
def monthly_returns(df):
    m_por = df.groupby(['month', 'label'])['retrf'].mean().reset_index()
    m_por_pivot = m_por.pivot(index='month', columns='label', values='retrf')
    return m_por_pivot

# %%
def draw(df,address):
    plt.figure(figsize=(10, 6))
    df.plot(kind='bar', color='skyblue')
    plt.title('Average Return of Each Portfolio', fontsize=16)
    plt.xlabel('Portfolio', fontsize=14)
    plt.ylabel('Average Return', fontsize=14)
    plt.grid(True, linestyle='--', alpha=0.7)
    plt.savefig(address)

# %%
df_value = assign_quintile(df, 'instown')
por_value = monthly_returns(df_value)
df_value
# Out:
#         stkcd stknme         conme      month    retrf   mktrf     smb  \
# 0           9   中国宝安  中国宝安集团股份有限公司 2013-07-01   9.0756  1.8833  5.1896
# 1           9   中国宝安  中国宝安集团股份有限公司 2013-08-01  -5.1363  4.5833  5.9407
# 2           9   中国宝安  中国宝安集团股份有限公司 2013-09-01   3.5840  3.3833  0.5848
# 3           9   中国宝安  中国宝安集团股份有限公司 2014-01-01  -1.0932 -3.6167  5.6921
# 4           9   中国宝安  中国宝安集团股份有限公司 2014-02-01  19.0704  0.9833  3.8899
# ...       ...    ...           ...        ...      ...     ...     ...
# 87427  900956   东贝B股  黄石东贝电器股份有限公司 2019-08-01  -5.3373 -1.6917 -0.6838
# 87428  900956   东贝B股  黄石东贝电器股份有限公司 2019-09-01  11.0761  0.4083  0.4298
# 87429  900956   东贝B股  黄石东贝电器股份有限公司 2019-10-01  12.3759  1.3083 -2.5189
# 87430  900956   东贝B股  黄石东贝电器股份有限公司 2019-11-01   0.5954 -1.6917 -0.8970
# 87431  900956   东贝B股  黄石东贝电器股份有限公司 2019-12-01   7.2701  6.2083  1.2581
#
#           hml     umd      size  ...   return12       roa       lev       ppe  \
# 0     -0.1922  6.1829  23.10871  ...  13.374120  0.007949  0.430605  0.086185
# 1      0.0976 -5.5041  23.10871  ...  13.374120  0.007949  0.430605  0.086185
# 2      2.8554  8.8693  23.10871  ...  13.374120  0.007949  0.430605  0.086185
# 3      1.1126  8.9357  23.28204  ...  46.591590  0.025973  0.432246  0.098660
# 4      0.6902 -1.8764  23.28204  ...  46.591590  0.025973  0.432246  0.098660
# ...       ...     ...       ...  ...        ...       ...       ...       ...
# 87427 -5.0887  4.6431  19.54512  ...  -4.492293  0.005443  0.598459  0.267594
# 87428  0.8208 -1.3250  19.54512  ...  -4.492293  0.005443  0.598459  0.267594
# 87429 -0.0984  3.5783  19.41050  ... -14.776860  0.010888  0.425125  0.269671
# 87430  0.1604 -0.1658  19.41050  ... -14.776860  0.010888  0.425125  0.269671
# 87431 -0.9661  1.0033  19.41050  ... -14.776860  0.010888  0.425125  0.269671
#
#          intang  numanalyst  instown           mv  quarter label
# 0      0.031575           0   6.4646  11874173952   2013Q3     3
# 1      0.031575           0   6.4646  11874173952   2013Q3     3
# 2      0.031575           0   6.4646  11874173952   2013Q3     3
# 3      0.029798           0   5.6741  11731143680   2014Q1     3
# 4      0.029798           0   5.6741  11731143680   2014Q1     3
# ...         ...         ...      ...          ...      ...   ...
# 87427  0.025879           0   0.0000    131675000   2019Q3     1
# 87428  0.025879           0   0.0000    131675000   2019Q3     1
# 87429  0.025286           0   0.0000    127880000   2019Q4     1
# 87430  0.025286           0   0.0000    127880000   2019Q4     1
# 87431  0.025286           0   0.0000    127880000   2019Q4     1
#
# [87432 rows x 21 columns]

# %%
df_size = assign_quintile(df, 'size')

# %%
por_size = monthly_returns(df_size)

# %%
portfolio_mean_size = por_size.mean(axis=0)
portfolio_mean_value = por_value.mean(axis=0)
portfolio_mean_value
# Out:
# label
# 1    1.072242
# 2    1.242938
# 3    1.354161
# 4    1.369625
# 5    1.564208
# dtype: float64

# %%
por_size.to_csv('size_portfolio_returns.csv')

# %%
por_value.to_csv('value_portfolio_returns.csv')

# %%
draw(portfolio_mean_size,'/Users/wwwzhang/Documents/FIN3210/Week3 Assignment/size.png')

# %%
draw(portfolio_mean_value,'/Users/wwwzhang/Documents/FIN3210/Week3 Assignment/value.png')

# %% [markdown]
# End of Question 1 & 2

# %%
# !pip install linearmodels
# Out:
# Collecting linearmodels
#   Downloading linearmodels-6.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.9 kB)
# Requirement already satisfied: numpy<3,>=1.22.3 in ./.venv/lib/python3.12/site-packages (from linearmodels) (2.1.1)
# Requirement already satisfied: pandas>=1.4.0 in ./.venv/lib/python3.12/site-packages (from linearmodels) (2.2.2)
# Collecting scipy>=1.8.0 (from linearmodels)
#   Downloading scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl.metadata (60 kB)
# Collecting statsmodels>=0.13.0 (from linearmodels)
#   Downloading statsmodels-0.14.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting mypy-extensions>=0.4 (from linearmodels)
#   Downloading mypy_extensions-1.0.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting Cython>=3.0.10 (from linearmodels)
#   Using cached Cython-3.0.11-py2.py3-none-any.whl.metadata (3.2 kB)
# Collecting pyhdfe>=0.1 (from linearmodels)
#   Downloading pyhdfe-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting formulaic>=1.0.0 (from linearmodels)
#   Downloading formulaic-1.0.2-py3-none-any.whl.metadata (6.8 kB)
# Collecting setuptools-scm<9.0.0,>=8.0.0 (from setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels)
#   Downloading setuptools_scm-8.1.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting interface-meta>=1.2.0 (from formulaic>=1.0.0->linearmodels)
#   Downloading interface_meta-1.3.0-py3-none-any.whl.metadata (6.7 kB)
# Collecting typing-extensions>=4.2.0 (from formulaic>=1.0.0->linearmodels)
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting wrapt>=1.0 (from formulaic>=1.0.0->linearmodels)
#   Downloading wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.12/site-packages (from pandas>=1.4.0->linearmodels) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in ./.venv/lib/python3.12/site-packages (from pandas>=1.4.0->linearmodels) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in ./.venv/lib/python3.12/site-packages (from pandas>=1.4.0->linearmodels) (2024.1)
# Requirement already satisfied: packaging>=20 in ./.venv/lib/python3.12/site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (24.1)
# Requirement already satisfied: setuptools in ./.venv/lib/python3.12/site-packages (from setuptools-scm<9.0.0,>=8.0.0->setuptools-scm[toml]<9.0.0,>=8.0.0->linearmodels) (59.5.0)
# Collecting patsy>=0.5.6 (from statsmodels>=0.13.0->linearmodels)
#   Downloading patsy-0.5.6-py2.py3-none-any.whl.metadata (3.5 kB)
# Requirement already satisfied: six in ./.venv/lib/python3.12/site-packages (from patsy>=0.5.6->statsmodels>=0.13.0->linearmodels) (1.16.0)
# Downloading linearmodels-6.0-cp312-cp312-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 1.1 MB/s eta 0:00:00a 0:00:010m
# Using cached Cython-3.0.11-py2.py3-none-any.whl (1.2 MB)
# Downloading formulaic-1.0.2-py3-none-any.whl (94 kB)
# Downloading mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Downloading pyhdfe-0.2.0-py3-none-any.whl (19 kB)
# Downloading scipy-1.14.1-cp312-cp312-macosx_12_0_arm64.whl (29.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.9/29.9 MB 3.4 MB/s eta 0:00:0000:0100:01
# Downloading setuptools_scm-8.1.0-py3-none-any.whl (43 kB)
# Downloading statsmodels-0.14.3-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 3.1 MB/s eta 0:00:00a 0:00:01
# Downloading interface_meta-1.3.0-py3-none-any.whl (14 kB)
# Downloading patsy-0.5.6-py2.py3-none-any.whl (233 kB)
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# Downloading wrapt-1.16.0-cp312-cp312-macosx_11_0_arm64.whl (38 kB)
# Installing collected packages: wrapt, typing-extensions, setuptools-scm, scipy, patsy, mypy-extensions, interface-meta, Cython, pyhdfe, statsmodels, formulaic, linearmodels
# Successfully installed Cython-3.0.11 formulaic-1.0.2 interface-meta-1.3.0 linearmodels-6.0 mypy-extensions-1.0.0 patsy-0.5.6 pyhdfe-0.2.0 scipy-1.14.1 setuptools-scm-8.1.0 statsmodels-0.14.3 typing-extensions-4.12.2 wrapt-1.16.0

# %%
from linearmodels.panel import PanelOLS

# %%
df = df.set_index(['stkcd','month'])
exog_vars = ['size', 'bm', 'return12', 'roa', 'lev', 'ppe', 'intang', 'numanalyst', 'instown']
exog = df[exog_vars]
endog = df['retrf']

# %%
mod = PanelOLS(endog, exog, entity_effects=True, time_effects=True)
res = mod.fit(cov_type='clustered', cluster_entity=True, cluster_time=True)
res.summary
# Out:
# <class 'linearmodels.compat.statsmodels.Summary'>
# """
#                           PanelOLS Estimation Summary
# ================================================================================
# Dep. Variable:                  retrf   R-squared:                        0.0123
# Estimator:                   PanelOLS   R-squared (Between):             -1202.4
# No. Observations:               87432   R-squared (Within):               0.0111
# Date:                Wed, Sep 18 2024   R-squared (Overall):             -38.009
# Time:                        21:12:11   Log-likelihood                -3.277e+05
# Cov. Estimator:             Clustered
#                                         F-statistic:                      117.96
# Entities:                        2035   P-value                           0.0000
# Avg Obs:                       42.964   Distribution:                 F(9,85296)
# Min Obs:                       3.0000
# Max Obs:                       93.000   F-statistic (robust):             13.944
#                                         P-value                           0.0000
# Time periods:                      93   Distribution:                 F(9,85296)
# Avg Obs:                       940.13
# Min Obs:                       388.00
# Max Obs:                       1825.0
#
#                              Parameter Estimates
# ==============================================================================
#             Parameter  Std. Err.     T-stat    P-value    Lower CI    Upper CI
# ------------------------------------------------------------------------------
# size          -3.6951     0.4626    -7.9881     0.0000     -4.6018     -2.7885
# bm             0.4304     0.8206     0.5245     0.6000     -1.1781      2.0388
# return12      -0.0048     0.0027    -1.7444     0.0811     -0.0102      0.0006
# roa            7.2873     3.0811     2.3651     0.0180      1.2483      13.326
# lev           -1.0791     0.6658    -1.6206     0.1051     -2.3841      0.2259
# ppe           -0.1872     1.0465    -0.1789     0.8580     -2.2382      1.8639
# intang         3.0122     2.3347     1.2902     0.1970     -1.5638      7.5883
# numanalyst     0.0003     0.0168     0.0167     0.9867     -0.0327      0.0333
# instown        0.0199     0.0173     1.1527     0.2490     -0.0139      0.0537
# ==============================================================================
#
# F-test for Poolability: 29.828
# P-value: 0.0000
# Distribution: F(2126,85296)
#
# Included effects: Entity, Time
# """

# %%
with open('panel_regression_results.txt', 'w') as file:
    file.write(res.summary.as_text())
